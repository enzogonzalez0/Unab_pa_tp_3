# %% [markdown]
# <a href="https://colab.research.google.com/github/enzogonzalez0/Unab_pa_tp_3/blob/main/Unab_pa_tp_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#ejercicio 2
class Punto:
  def __init__(self, x, y):
    self.x = x
    self.y = y
  def eje_x(self):
    return self.x
  def eje_y(self):
    return self.y
  def impresion(self):
    return f"({self.x}, {self.y})"
  def opuesto(self):
    return Punto(-self.x, -self.y)

  #ejercicio 3
  class Linea:
    def __init__ (self, _punto_a, _punto_B):
      def._punto_a = _punto_a
      def._punto_b = _punto_B
    def mueve_derecha (self, distancia):
      self._punto_a.x += distancia
      self._punto_b.x += distancia
    def mueve_izquierda (self, distancia):
      self._punto_a.x -= distancia
      self._punto_b.x -= distancia
    def mueve_arriba (self. distancia):
      self._punto_a.y += distancia
      self._punto_b.y += distancia
    def mueve_abajo (self. distancia):
      self._punto_a.y -= distancia
      self._punto_b.y -= distancia
      def mostrar(self):
        return f"Linea de{self._punto_a.impresion()} a {self._punto_b.impresion()}"
    #ejercicio 4
    class Cancion:
      def __init__ (self, titulo, autor):
        self.titulo = titulo
        self.autor = autor
      def get_titulo(self):
        return self.titulo
      def get_autor(self):
        return self.autor
      def set_titulo(Self):
         self.titulo
      def set_autor(self):
           self.autor
